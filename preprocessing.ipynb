# %% [markdown]
# # Preprocessing
# Here, the data from the `/data/` folder is read and processed to DataFrames. Labels are added to indicate whether it is a bot activity or not.

# %%
import pandas as pd

# %% [markdown]
# ## Import and merge

# %%
# Read the JSON data into a DataFrame
df_bot = pd.read_json('data/bot_activities.json')

# Add a new column 'is_bot' with value true for each entry
df_bot['is_bot'] = True

df_bot.head()
# Out:
#                        date                 activity    contributor  \
# 0 2022-11-25 09:55:19+00:00  Commenting pull request  AmplabJenkins
# 1 2022-11-25 09:55:23+00:00  Commenting pull request  AmplabJenkins
# 2 2022-11-25 09:55:26+00:00  Commenting pull request  AmplabJenkins
# 3 2022-11-25 09:55:27+00:00  Commenting pull request   analysis-bot
# 4 2022-11-25 09:55:47+00:00          Pushing commits       neos-bot
#
#               repository                                            comment  \
# 0           apache/spark   {'length': 40, 'GH_node': 'IC_kwDOAQXtWs5PHEhk'}
# 1           apache/spark   {'length': 40, 'GH_node': 'IC_kwDOAQXtWs5PHEj2'}
# 2           apache/spark   {'length': 40, 'GH_node': 'IC_kwDOAQXtWs5PHEl_'}
# 3  facebook/react-native  {'length': 204, 'GH_node': 'IC_kwDOAbrxp85PHEmN'}
# 4  neos/neos-ui-compiled                                                NaN
#
#                                         pull_request     conversation  \
# 0  {'id': 38782, 'title': '[SPARK-38728][SQL] Tes...  {'comments': 2}
# 1  {'id': 38781, 'title': '[SPARK-41246][core] So...  {'comments': 1}
# 2  {'id': 38780, 'title': '[SPARK-41185][K8S][DOC...  {'comments': 3}
# 3  {'id': 35471, 'title': 'fix: update CircleCI c...  {'comments': 1}
# 4                                                NaN              NaN
#
#                                              payload gitref review issue  \
# 0                                                NaN    NaN    NaN   NaN
# 1                                                NaN    NaN    NaN   NaN
# 2                                                NaN    NaN    NaN   NaN
# 3                                                NaN    NaN    NaN   NaN
# 4  {'pushed_commits': 1, 'pushed_distinct_commits...    NaN    NaN   NaN
#
#   release page  is_bot
# 0     NaN  NaN    True
# 1     NaN  NaN    True
# 2     NaN  NaN    True
# 3     NaN  NaN    True
# 4     NaN  NaN    True

# %%
# Read the JSON data into a DataFrame
df_human = pd.read_json('data/human_activities.json')

# Add a new column 'is_bot' with value false for each entry
df_human['is_bot'] = False

df_human.head()
# Out:
#                        date              activity  contributor  repository  \
# 0 2022-11-25 09:54:52+00:00    Forking repository       769988      735966
# 1 2022-11-25 09:56:08+00:00      Commenting issue       755587      484533
# 2 2022-11-25 09:56:55+00:00       Pushing commits       769988      785873
# 3 2022-11-25 10:02:04+00:00  Opening pull request       769988      735966
# 4 2022-11-25 10:02:36+00:00       Pushing commits       574687      378469
#
#                                              payload  \
# 0                                                 {}
# 1                                                NaN
# 2  {'pushed_commits': 1, 'pushed_distinct_commits...
# 3           {'pr_commits': 1, 'pr_changed_files': 1}
# 4  {'pushed_commits': 1, 'pushed_distinct_commits...
#
#                                      comment  \
# 0                                        NaN
# 1     {'length': 7, 'GH_node': 'anonymised'}
# 2                                        NaN
# 3  {'length': 1559, 'GH_node': 'anonymised'}
# 4                                        NaN
#
#                                                issue     conversation  \
# 0                                                NaN              NaN
# 1  {'id': 28, 'title': 'anonymised', 'created_at'...  {'comments': 3}
# 2                                                NaN              NaN
# 3                                                NaN  {'comments': 1}
# 4                                                NaN              NaN
#
#                                         pull_request gitref review release  \
# 0                                                NaN    NaN    NaN     NaN
# 1                                                NaN    NaN    NaN     NaN
# 2                                                NaN    NaN    NaN     NaN
# 3  {'id': 1206, 'title': 'anonymised', 'created_a...    NaN    NaN     NaN
# 4                                                NaN    NaN    NaN     NaN
#
#   page  is_bot
# 0  NaN   False
# 1  NaN   False
# 2  NaN   False
# 3  NaN   False
# 4  NaN   False

# %%
# Concatenate the two dataframes
merged_df = pd.concat([df_bot, df_human])

# Reset index of the merged dataframes
merged_df.reset_index(drop=True, inplace=True)

merged_df.head()
# Out:
#                        date                 activity    contributor  \
# 0 2022-11-25 09:55:19+00:00  Commenting pull request  AmplabJenkins
# 1 2022-11-25 09:55:23+00:00  Commenting pull request  AmplabJenkins
# 2 2022-11-25 09:55:26+00:00  Commenting pull request  AmplabJenkins
# 3 2022-11-25 09:55:27+00:00  Commenting pull request   analysis-bot
# 4 2022-11-25 09:55:47+00:00          Pushing commits       neos-bot
#
#               repository                                            comment  \
# 0           apache/spark   {'length': 40, 'GH_node': 'IC_kwDOAQXtWs5PHEhk'}
# 1           apache/spark   {'length': 40, 'GH_node': 'IC_kwDOAQXtWs5PHEj2'}
# 2           apache/spark   {'length': 40, 'GH_node': 'IC_kwDOAQXtWs5PHEl_'}
# 3  facebook/react-native  {'length': 204, 'GH_node': 'IC_kwDOAbrxp85PHEmN'}
# 4  neos/neos-ui-compiled                                                NaN
#
#                                         pull_request     conversation  \
# 0  {'id': 38782, 'title': '[SPARK-38728][SQL] Tes...  {'comments': 2}
# 1  {'id': 38781, 'title': '[SPARK-41246][core] So...  {'comments': 1}
# 2  {'id': 38780, 'title': '[SPARK-41185][K8S][DOC...  {'comments': 3}
# 3  {'id': 35471, 'title': 'fix: update CircleCI c...  {'comments': 1}
# 4                                                NaN              NaN
#
#                                              payload gitref review issue  \
# 0                                                NaN    NaN    NaN   NaN
# 1                                                NaN    NaN    NaN   NaN
# 2                                                NaN    NaN    NaN   NaN
# 3                                                NaN    NaN    NaN   NaN
# 4  {'pushed_commits': 1, 'pushed_distinct_commits...    NaN    NaN   NaN
#
#   release page  is_bot
# 0     NaN  NaN    True
# 1     NaN  NaN    True
# 2     NaN  NaN    True
# 3     NaN  NaN    True
# 4     NaN  NaN    True

# %% [markdown]
# ## Feature engineering
# The merged DataFrame is processed further to make it more interpretable for any kind of model or visualization. For instance:
# - comment: {'length': 0, 'GH_node': 'anonymised'}
#
# will be converted to:
# - comment_length = 0
# - comment_GH_node: 'anonymised'

# %% [markdown]
# ### Issue feature
# We are interested in keeping `created_at`, `status` and `closed_at` features. For `status` we create a boolean column, indicating whether it's open or closed

# %%
# Flatten the nested JSON structure within the 'issue' column
issue_df = pd.json_normalize(merged_df['issue'])

# Rename the columns to avoid conflicts with existing columns
issue_df.columns = [f"issue_{col}" for col in issue_df.columns]

# %%
# Map 'status' values to boolean values
issue_df['issue_is_closed'] = issue_df['issue_status'].map({'closed': True, 'open': False})

# %%
# Filter out uninteresting columns
issue_df = issue_df[['issue_created_at', 'issue_is_closed', 'issue_closed_at']]
issue_df.head()
# Out:
#   issue_created_at issue_is_closed issue_closed_at
# 0              NaN             NaN             NaN
# 1              NaN             NaN             NaN
# 2              NaN             NaN             NaN
# 3              NaN             NaN             NaN
# 4              NaN             NaN             NaN

# %% [markdown]
# ### Pull request feature
# We are interested in keeping `created_at`, `status` and `closed_at` features. For `status` we create a boolean column, indicating whether it's open or closed

# %%
# Flatten the nested JSON structure within the 'pull_request' column
pull_request_df = pd.json_normalize(merged_df['pull_request'])

# Rename the columns to avoid conflicts with existing columns
pull_request_df.columns = [f"pull_request_{col}" for col in pull_request_df.columns]

# %%
# Map 'status' values to boolean values
pull_request_df['pull_request_is_closed'] = pull_request_df['pull_request_status'].map({'closed': True, 'open': False})

# %%
# Filter out uninteresting columns
pull_request_df = pull_request_df[['pull_request_created_at', 'pull_request_is_closed', 'pull_request_closed_at']]
pull_request_df.head()
# Out:
#      pull_request_created_at pull_request_is_closed pull_request_closed_at
# 0  2022-11-24T04:42:12+00:00                  False                   None
# 1  2022-11-24T04:37:11+00:00                  False                   None
# 2  2022-11-24T04:05:07+00:00                  False                   None
# 3  2022-11-25T09:23:54+00:00                  False                   None
# 4                        NaN                    NaN                    NaN

# %% [markdown]
# ### Conversation feature
# This simply represents the amount of comments, so we extract that

# %%
# Flatten the nested JSON structure within the 'issue' column
conversation_df = pd.json_normalize(merged_df['conversation'])
conversation_df.columns = ['amount_of_comments']

# %%
# Replace NaN values with 0's and convert to int
conversation_df['amount_of_comments'] = conversation_df['amount_of_comments'].fillna(0).astype(int)
conversation_df.head()
# Out:
#    amount_of_comments
# 0                   2
# 1                   1
# 2                   3
# 3                   1
# 4                   0

# %% [markdown]
# ### Payload feature
# We are interested in keeping `pr_commits`, `pr_changed_files`, `pushed_commits` and `distinct_pushed_commits` features

# %%
# Flatten the nested JSON structure within the 'payload' column
payload_df = pd.json_normalize(merged_df['payload'])

# Rename the columns to avoid conflicts with existing columns
payload_df.columns = [f"{col}" for col in payload_df.columns]

# %%
# Filter out uninteresting columns
payload_df = payload_df[['pr_commits', 'pr_changed_files', 'pushed_commits', 'pushed_distinct_commits']]
payload_df.head()
# Out:
#    pr_commits  pr_changed_files  pushed_commits  pushed_distinct_commits
# 0         NaN               NaN             NaN                      NaN
# 1         NaN               NaN             NaN                      NaN
# 2         NaN               NaN             NaN                      NaN
# 3         NaN               NaN             NaN                      NaN
# 4         NaN               NaN             1.0                      1.0

# %% [markdown]
# ### Comment feature
# We are only interested in keeping the `length`

# %%
# Flatten the nested JSON structure within the 'payload' column
comment_df = pd.json_normalize(merged_df['comment'])
comment_df = comment_df[['length']]
comment_df.columns = ['comment_length']

comment_df.head()
# Out:
#    comment_length
# 0            40.0
# 1            40.0
# 2            40.0
# 3           204.0
# 4             NaN

# %% [markdown]
# ## Merge and save
# Here we also remove `gitref`, `review`, `release` and `page`

# %%
# Concatenate the engineered features with the merged_df
merged_df = pd.concat([merged_df, issue_df, pull_request_df, conversation_df, payload_df, comment_df], axis=1)

# Remove old columns and uninteresting columns
merged_df.drop(columns=['issue', 'pull_request', 'conversation', 'payload', 'comment', 'gitref', 'review', 'release', 'page'], inplace=True)

# %%
# Parse date columns to datetime
date_columns = ['date', 'issue_created_at', 'issue_closed_at', 'pull_request_created_at', 'pull_request_closed_at']
merged_df[date_columns] = merged_df[date_columns].apply(pd.to_datetime)

merged_df.head()
# Out:
#                        date                 activity    contributor  \
# 0 2022-11-25 09:55:19+00:00  Commenting pull request  AmplabJenkins
# 1 2022-11-25 09:55:23+00:00  Commenting pull request  AmplabJenkins
# 2 2022-11-25 09:55:26+00:00  Commenting pull request  AmplabJenkins
# 3 2022-11-25 09:55:27+00:00  Commenting pull request   analysis-bot
# 4 2022-11-25 09:55:47+00:00          Pushing commits       neos-bot
#
#               repository  is_bot issue_created_at issue_is_closed  \
# 0           apache/spark    True              NaT             NaN
# 1           apache/spark    True              NaT             NaN
# 2           apache/spark    True              NaT             NaN
# 3  facebook/react-native    True              NaT             NaN
# 4  neos/neos-ui-compiled    True              NaT             NaN
#
#   issue_closed_at   pull_request_created_at pull_request_is_closed  \
# 0             NaT 2022-11-24 04:42:12+00:00                  False
# 1             NaT 2022-11-24 04:37:11+00:00                  False
# 2             NaT 2022-11-24 04:05:07+00:00                  False
# 3             NaT 2022-11-25 09:23:54+00:00                  False
# 4             NaT                       NaT                    NaN
#
#   pull_request_closed_at  amount_of_comments  pr_commits  pr_changed_files  \
# 0                    NaT                   2         NaN               NaN
# 1                    NaT                   1         NaN               NaN
# 2                    NaT                   3         NaN               NaN
# 3                    NaT                   1         NaN               NaN
# 4                    NaT                   0         NaN               NaN
#
#    pushed_commits  pushed_distinct_commits  comment_length
# 0             NaN                      NaN            40.0
# 1             NaN                      NaN            40.0
# 2             NaN                      NaN            40.0
# 3             NaN                      NaN           204.0
# 4             1.0                      1.0             NaN

# %%
# Save
merged_df.to_csv('data/preprocessed_data.csv', index=False)
